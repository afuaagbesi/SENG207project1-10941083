# %% [markdown]
# ## Name: Mawuena Efua Agbesi
#
# ## ID: 10941083
#
# ## Department: Computer Engineering

# %%
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as mpl
import pandas as pds

# %%
data = pds.read_csv('data.csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# ###  Replacement method

# %%
Columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
for column in Columns:
    data[column].fillna(data[column].mean(), inplace=True)

# %% [markdown]
#  When dealing with missing values in data analysis, it is common to use the mean of the column to replace null values instead of removing rows with missing values. This is because removing rows can lead to a loss of information and a reduction in the sample size, which can negatively affect the accuracy and representativeness of the analysis. To avoid this, replacing null values with the mean of the column can retain the sample size and provide a reasonable estimate of the missing data. However, this method assumes that the missing values are randomly distributed and that the data follows a normal distribution. If these assumptions are not met, using the mean may not accurately represent the missing data. In such cases, other techniques like interpolation, imputation, or removing rows/columns may be more appropriate.

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Checking for duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Therefore there are no duplicate values.

# %% [markdown]
# ### Statistical Inferences of Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ### Histogram of individual columns

# %%
clear_id=data.drop('ID', axis = 1)
clear_id.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
Columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']

# %%
for column in Columns:
    mpl.title(f'{column} against Quality')
    sbn.barplot(x='quality',y=column, data=data)
    mpl.figure(figsize=(15,9))
    mpl.show()

# %%
Acids=['fixed acidity','volatile acidity','citric acid']

# %%
for acid in Acids:
    mpl.title(f'pH plotted against {acid}' )
    sbn.scatterplot(x=acid , y='pH',data=data)
    mpl.figure(figsize=(12,10))
    mpl.show()

# %%
mean_quality=data['quality'].mean()
compared_mean=data['quality']<mean_quality
mpl.pie(compared_mean.value_counts(),labels=['Values less than mean','Values greater than mean'])
mpl.title('QUality values compared to the mean') 
mpl.show()

# %%
sbn.pairplot(data,vars=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides'])

# %% [markdown]
# ### Data correlation

# %%
corr_matrix=data.corr()
sbn.heatmap(corr_matrix,annot=True,cmap='hot')
mpl.figure(figsize=(18,10))
mpl.show()
